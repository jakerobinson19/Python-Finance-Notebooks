# %% [markdown]
# # Discounted Cash Flow (DCF) and EPS Valuation
# #### Financial Data and Statements Provided by the financialmodellingprep json API
#
# Valuation is the analytical process of determining the current (or projected) worth of an asset or a company. There are many techniques used for doing a valuation. Here, we evaluate a company using the Discounted Cash Flow and Discount Dividend Model methods.
#
# Discounted cash flow (DCF) is a valuation method used to estimate the value of an investment based on its future cash flows. DCF analysis attempts to figure out the value of an investment today, based on projections of how much money it will generate in the future.
#
# The dividend discount model (DDM) is a quantitative method used for predicting the price of a company's stock based on the theory that its present-day price is worth the sum of all of its future dividend payments when discounted back to their present value.
#
# Financial data is pulled and parsed from **financialmodellingprep.com** using **pd.read_json**.
#
# **Important**: To use the underlying API you need to get a free API key from https://financialmodelingprep.com/developer/docs/pricing/
#
# All graphs are interactive. You can zoom in or hover over for more information.
#
# Note: This notebook is a simple show case of valuation models using python. In no way do I claim that these are comprehensive. For example, **companies which experience high variability or fluctuations in cashflows or earnings per share may not be accurately predicted with these models**. You must do your own due diligence when it comes to investing and to understand if these models are suitable for the asset you are evaluating.
#
# #### Built With
#  * Python 3
#  * Plotly
#
# ###### Written by: Jake Robinson (https://github.com/jakerobinson19)

# %%
#import necessary packages
import pandas as pd
import json
import requests

# iPython display packages for hiding underlying code
from IPython.display import HTML
from IPython.display import display

# Plotly visualization packages
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
def format_data(data):
    data.date = data.date.astype('datetime64')
    data = data.drop(['link',
                      'finalLink',
                      'symbol',
                      'acceptedDate'], axis=1).T
    data.columns = data.iloc[0].astype(str).str[:10]
    data = data[1:]
    #del data.columns.name
    
    return(data)

def log_error(msg, json_response):
    print("ERROR: {}".format(msg))
    print("JSON RESPONSE: {}".format(json_response))
    print("Please check your API Key")

def generate_url(ticker, api_key, p_type, statement):
    return('https://financialmodelingprep.com/api/v3/{}/{}?period={}&apikey={}'.format(statement, 
                                                                                       ticker,
                                                                                       p_type,
                                                                                       api_key))


def get_historical_prices(ticker, api_key):
    url = 'https://financialmodelingprep.com/api/v3/historical-price-full/{}?&apikey={}'.format(ticker,api_key)
    p = requests.get(url)
    
    prices_json = json.loads(p.text)
    try:
        prices = pd.DataFrame(prices_json["historical"], columns=['date','open','high','low','close'])
        prices = prices.set_index('date')
    
    except:
        log_error("Historical Prices Are Not Available at this time", prices_json)
        prices = None
        
    return(prices)


def get_profile(ticker, api_key):
    url = generate_url(ticker, api_key, '0', 'profile')
    
    profile = pd.read_json(url)
    profile = profile.T
    #del profile.columns.name
    
    return(profile)

def get_quote(ticker, api_key):
    url = generate_url(ticker, api_key, '0', 'quote')
    
    quote = pd.read_json(url)
    quote = quote.T
    #del quote.columns.name
    
    quote.columns = [ticker]
    quote = quote.loc[['name', 'exchange',
                       'price','yearHigh',
                       'yearLow','marketCap',
                       'volume','eps','pe',
                       'sharesOutstanding']]
    quote.index = ['Name','Exchange',
                  'Price','52-wk High',
                  '52 wk Low','Market Cap',
                  'Volume','EPS','P/E',
                  'Shares Outstanding']
    
    return(quote)

def get_balance_sheet(ticker, api_key, p_type, periods): #periods
    url = generate_url(ticker, api_key, p_type, 'balance-sheet-statement')
    
    b_sheet = pd.read_json(url)
    balance_sheet = format_data(b_sheet)
    
    return(balance_sheet.iloc[:, : periods])

def get_income_statement(ticker, api_key, p_type): #periods
    url = generate_url(ticker, api_key, p_type, 'income-statement')
    
    inc_statement = pd.read_json(url)
    income_statement = format_data(inc_statement)
    
    return(income_statement)

def get_cash_flow_statement(ticker, api_key, p_type, periods):
    url = generate_url(ticker, api_key, p_type, 'cash-flow-statement')
    
    cf_statement = pd.read_json(url)
    cashflow_statment = format_data(cf_statement)
    
    return(cashflow_statment.iloc[:, : periods])
    
#res = requests.get(url, timeout=5)
# method used exclusively for hiding the code in the jupyter notebook
tag = HTML('''<script>
code_show=true; 
function code_toggle() {
    if (code_show){
        $('div.cell.code_cell.rendered.selected div.input').hide();
    } else {
        $('div.cell.code_cell.rendered.selected div.input').show();
    }
    code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
To show/hide this cell's raw code input, click <a href="javascript:code_toggle()">here</a>.''')

display(tag)
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#     if (code_show){
#         $('div.cell.code_cell.rendered.selected div.input').hide();
#     } else {
#         $('div.cell.code_cell.rendered.selected div.input').show();
#     }
#     code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# To show/hide this cell's raw code input, click <a href="javascript:code_toggle()">here</a>.

# %% [markdown]
# ### Input Ticker and API Key

# %%
ticker = 'AAPL'
api_key = ''

# %% [markdown]
# #### DCF INPUTS

# %%
# growth rate for cash flows
g_rate = 0.20

# growth years
g_years = 10

# terminal growth rate and period
t_rate = 0.04

# terminal period years
t_years = 10

# discount rate
discount_rate = 0.12

# %% [markdown]
# # =========================================
#
# ## Stock Information

# %%
quote = get_quote(ticker, api_key) 
quote
# Out:
#                              AAPL
# Name                   Apple Inc.
# Exchange                   NASDAQ
# Price                     338.312
# 52-wk High                 354.77
# 52 wk Low                   190.3
# Market Cap          1466353582080
# Volume                   43064299
# EPS                        12.728
# P/E                       26.5801
# Shares Outstanding     4334329699

# %% [markdown]
# ## Stock Chart

# %%
p = get_historical_prices(ticker, api_key)

fig = go.Figure(data=[go.Candlestick(x=p.index,
                open=p['open'],
                high=p['high'],
                low=p['low'],
                close=p['close'])])

fig.update_layout(
    title="{} Stock Chart".format(ticker),
    xaxis_title="Year",
    yaxis_title="Price")

display(tag)
fig.show()
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#     if (code_show){
#         $('div.cell.code_cell.rendered.selected div.input').hide();
#     } else {
#         $('div.cell.code_cell.rendered.selected div.input').show();
#     }
#     code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# To show/hide this cell's raw code input, click <a href="javascript:code_toggle()">here</a>.
# <div>
#
#
#             <div id="b5ba2d5e-d9f4-4046-a1eb-fff2c2f51e62" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b5ba2d5e-d9f4-4046-a1eb-fff2c2f51e62")) {
#                     Plotly.newPlot(
#                         'b5ba2d5e-d9f4-4046-a1eb-fff2c2f51e62',
#                         [{"close": [335.9, 352.84, 343.99, 333.46, 331.5, 322.32, 325.12, 323.34, 321.85, 317.94, 318.25, 318.11, 316.73, 318.89, 316.85, 319.23, 313.14, 314.96, 307.71, 309.54, 307.65, 311.41, 315.01, 310.13, 303.74, 300.63, 297.56, 293.16, 289.07, 293.8, 287.73, 278.58, 283.17, 282.97, 275.03, 276.1, 268.37, 276.93, 282.8, 286.69, 284.43, 287.05, 273.25, 267.99, 266.07, 259.43, 262.47, 241.41, 244.93, 240.91, 254.29, 254.81, 247.74, 258.44, 245.52, 246.88, 224.37, 229.24, 244.78, 246.67, 252.86, 242.21, 277.97, 248.23, 275.43, 285.34, 266.17, 289.03, 292.92, 302.74, 289.32, 298.81, 273.36, 273.52, 292.65, 288.08, 298.18, 313.05, 320.3, 323.62, 319.0, 324.95, 324.87, 327.2, 319.61, 321.55, 320.03, 325.21, 321.45, 318.85, 308.66, 309.51, 323.87, 324.34, 317.69, 308.95, 318.31, 319.23, 317.7, 316.57, 318.73, 315.24, 311.34, 312.68, 316.96, 310.33, 309.63, 303.19, 298.39, 299.8, 297.43, 300.35, 293.65, 291.52, 289.8, 289.91, 284.27, 284.0, 279.44, 280.02, 279.74, 280.41, 279.86, 275.15, 271.46, 270.77, 268.48, 266.92, 270.71, 265.58, 261.74, 259.45, 264.16, 267.25, 267.84, 264.29, 266.37, 261.78, 262.01, 263.19, 266.29, 267.1, 265.76, 262.64, 264.47, 261.96, 262.2, 260.14, 259.43, 257.24, 257.13, 257.5, 255.82, 248.76, 243.26, 243.29, 249.05, 246.58, 243.58, 243.18, 239.96, 240.51, 236.41, 235.28, 234.37, 235.32, 235.87, 236.21, 230.09, 227.03, 224.4, 227.06, 227.01, 220.82, 218.96, 224.59, 223.97, 218.82, 219.89, 221.03, 217.68, 218.72, 217.73, 220.96, 222.77, 220.7, 219.9, 218.75, 223.09, 223.59, 216.7, 214.17, 213.26, 213.28, 209.19, 205.7, 208.74, 209.01, 205.53, 204.16, 206.49, 202.64, 212.46, 212.64, 210.36, 210.35, 206.5, 201.74, 202.75, 208.97, 200.48, 200.99, 203.43, 199.04, 197.0, 193.34, 204.02, 208.43, 213.04, 208.78, 209.68, 207.74, 207.02, 208.67, 208.84, 207.22, 202.59, 205.66, 203.35, 204.5, 205.21, 203.3, 201.75, 203.23, 201.24, 200.02, 204.23, 204.41, 202.73, 201.55, 197.92, 199.74, 199.8, 195.57, 198.58, 198.78, 199.46, 197.87, 198.45, 193.89, 192.74, 194.15, 194.19, 194.81, 192.58, 190.15, 185.22, 182.54, 179.64, 173.3, 175.07, 178.3, 177.38, 178.23, 178.97, 179.66, 182.78, 186.6, 183.09, 189.0, 190.08, 190.92, 188.66, 185.72, 197.18, 200.72, 202.9, 202.86, 208.48, 211.75, 209.15, 210.52, 200.67, 204.61, 204.3, 205.28, 207.16, 207.48, 204.53, 203.86, 203.13, 199.25, 199.23, 198.87, 198.95, 200.62, 199.5, 200.1, 197.0, 195.69, 195.35, 194.02, 191.24, 189.95, 188.72, 188.47, 186.79, 188.74, 191.05, 195.09, 188.16, 186.53, 188.02, 186.12, 183.73, 181.71, 180.91, 178.9, 172.91, 172.5, 174.52, 175.53, 175.85, 174.97, 173.15, 174.87, 174.33, 174.23, 172.97, 171.06, 172.03, 170.93, 170.42, 170.8, 170.18, 170.89, 169.43, 170.41, 170.94, 174.24, 174.18, 171.25, 166.52, 166.44, 165.25, 154.68, 156.3, 157.76, 152.7, 153.92, 153.3, 156.82, 155.86, 154.94, 153.07, 150.0, 152.29, 153.8, 153.31, 150.75, 147.93, 148.26, 142.19, 157.92, 157.74, 156.23, 156.15, 157.17, 146.83, 150.73, 156.83, 160.89, 166.07, 163.94, 165.48, 170.95, 169.1, 168.63, 169.6, 168.49, 174.72, 176.69, 184.82, 178.58, 179.55, 180.94, 174.24, 174.62, 172.29, 176.78, 176.98, 185.86, 193.53, 191.41, 186.8, 192.23, 194.17, 204.47, 208.49, 209.95, 203.77, 201.59, 207.48, 222.22, 218.86, 213.3, 212.24, 216.3, 219.8, 215.09, 222.73, 220.65, 219.31, 216.02, 221.19, 222.15, 217.36, 222.11, 214.45, 216.36, 226.87, 223.77, 224.29, 227.99, 232.07, 229.28, 227.26, 225.74, 224.95, 220.42, 222.19, 220.79, 217.66, 220.03, 218.37, 218.24, 217.88, 223.84, 226.41, 221.07, 223.85, 218.33, 221.3, 223.1, 226.87, 228.36, 227.63, 225.03, 222.98, 219.7, 217.94, 216.16, 215.49, 215.05, 215.04, 215.46, 217.58, 213.32, 210.24, 209.75, 208.87, 207.53, 208.88, 207.25, 207.11, 209.07, 207.99, 207.39, 201.5, 190.29, 189.91, 190.98, 194.21, 194.82, 193.0, 191.61, 191.44, 191.88, 190.4, 191.45, 190.91, 191.33, 191.03, 187.88, 190.35, 190.58, 187.97, 185.4, 183.92, 187.18, 185.11, 185.5, 184.16, 184.43, 182.17, 184.92, 185.46, 186.5, 185.69, 188.74, 188.84, 190.8, 190.7, ...

# %% [markdown]
# ## Balance Sheet

# %%
b = get_balance_sheet(ticker, api_key, 'annual', 5)
b
# Out:
# date                                       2019-09-28    2018-09-29  \
# fillingDate                                2019-10-31    2018-11-05
# period                                             FY            FY
# cashAndCashEquivalents                    48844000000   25913000000
# shortTermInvestments                      51713000000   40388000000
# cashAndShortTermInvestments              100557000000   66301000000
# netReceivables                            22926000000   23186000000
# inventory                                  4106000000    3956000000
# otherCurrentAssets                        35230000000   37896000000
# totalCurrentAssets                       162819000000  131339000000
# propertyPlantEquipmentNet                 37378000000   41304000000
# goodwill                                            0             0
# intangibleAssets                                    0             0
# goodwillAndIntangibleAssets                         0             0
# longTermInvestments                      105341000000  170799000000
# taxAssets                                           0             0
# otherNonCurrentAssets                     32978000000   22283000000
# totalNonCurrentAssets                    175697000000  234386000000
# otherAssets                               86606000000  152694000000
# totalAssets                              338516000000  365725000000
# accountPayables                           46236000000   55888000000
# shortTermDebt                             10260000000    8784000000
# taxPayables                                         0             0
# deferredRevenue                            5522000000    7543000000
# otherCurrentLiabilities                   43700000000   44651000000
# totalCurrentLiabilities                  105718000000  116866000000
# longTermDebt                              91807000000   93735000000
# deferredRevenueNonCurrent                           0    2797000000
# deferredTaxLiabilitiesNonCurrent                    0             0
# otherNonCurrentLiabilities                50503000000   45180000000
# totalNonCurrentLiabilities               142310000000  141712000000
# otherLiabilities                                    0             0
# totalLiabilities                         248028000000  258578000000
# commonStock                                4443236000    4754986000
# retainedEarnings                          45898000000   70400000000
# accumulatedOtherComprehensiveIncomeLoss    -584000000   -3454000000
# othertotalStockholdersEquity              40730764000   35446014000
# totalStockholdersEquity                   90488000000  107147000000
# totalLiabilitiesAndStockholdersEquity    338516000000  365725000000
# totalInvestments                         157054000000  211187000000
# totalDebt                                102067000000  102519000000
# netDebt                                   53223000000   76606000000
#
# date                                       2017-09-30    2016-09-24  \
# fillingDate                                2017-11-03    2016-10-26
# period                                             FY            FY
# cashAndCashEquivalents                    20289000000   20484000000
# shortTermInvestments                      53892000000   46671000000
# cashAndShortTermInvestments               74181000000   67155000000
# netReceivables                            17874000000   15754000000
# inventory                                  4855000000    2132000000
# otherCurrentAssets                        31735000000   21828000000
# totalCurrentAssets                       128645000000  106869000000
# propertyPlantEquipmentNet                 33783000000   27010000000
# goodwill                                   5717000000    5414000000
# intangibleAssets                           2298000000    3206000000
# goodwillAndIntangibleAssets                8015000000    8620000000
# longTermInvestments                      194714000000  170430000000
# taxAssets                                           0             0
# otherNonCurrentAssets                     10162000000    8757000000
# totalNonCurrentAssets                    246674000000  214817000000
# otherAssets                              150984000000  132516000000
# totalAssets                              375319000000  321686000000
# accountPayables                           49049000000   37294000000
# shortTermDebt                              6496000000    3500000000
# taxPayables                                         0             0
# deferredRevenue                            7548000000    8080000000
# otherCurrentLiabilities                   37721000000   30132000000
# totalCurrentLiabilities                  100814000000   79006000000
# longTermDebt                               6496000000    3500000000
# deferredRevenueNonCurrent                  2836000000    2930000000
# deferredTaxLiabilitiesNonCurrent                    0             0
# otherNonCurrentLiabilities                40415000000   36074000000
# totalNonCurrentLiabilities               140458000000  114431000000
# otherLiabilities                                    0             0
# totalLiabilities                         241272000000  193437000000
# commonStock                                5126201000    5336166000
# retainedEarnings                          98330000000   96364000000
# accumulatedOtherComprehensiveIncomeLoss    -150000000     634000000
# othertotalStockholdersEquity              30740799000   25914834000
# totalStockholdersEquity                  134047000000  128249000000
# totalLiabilitiesAndStockholdersEquity    375319000000  321686000000
# totalInvestments                         248606000000  217101000000
# totalDebt                                103703000000   78927000000
# netDebt                                   83414000000   58443000000
#
# date                                       2015-09-26
# fillingDate                                2015-10-28
# period                                             FY
# cashAndCashEquivalents                    21120000000
# shortTermInvestments                      20481000000
# cashAndShortTermInvestments               41601000000
# netReceivables                            16849000000
# inventory                                  2349000000
# otherCurrentAssets                        28579000000
# totalCurrentAssets                        89378000000
# propertyPlantEquipmentNet                 22471000000
# goodwill                                   5116000000
# intangibleAssets                           3893000000
# goodwillAndIntangibleAssets                9009000000
# longTermInvestments                      164065000000
# taxAssets                                  5546000000
# otherNonCurrentAssets                        10000000
# totalNonCurrentAssets                    201101000000
# otherAssets                              149140000000
# totalAssets                              290479000000
# accountPayables                           35490000000
# shortTermDebt                              2500000000
# taxPayables                                         0
# deferredRevenue                            8940000000
# otherCurrentLiabilities                   33680000000
# totalCurrentLiabilities                   80610000000
# longTermDebt                               2500000000
# deferredRevenueNonCurrent                  3624000000
# deferredTaxLiabilitiesNonCurrent                    0
# otherNonCurrentLiabilities                33427000000
# totalNonCurrentLiabilities                90514000000
# otherLiabilities                                    0
# totalLiabilities                         171124000000
# commonStock                                5578753000
# retainedEarnings                          92284000000
# accumulatedOtherComprehensiveIncomeLoss    -345000000
# othertotalStockholdersEquity              21837247000
# totalStockholdersEquity                  119355000000
# totalLiabilitiesAndStockholdersEquity    290479000000
# totalInvestments                         184546000000
# totalDebt                                 55963000000
# netDebt                                   34843000000

# %% [markdown]
# ## Income Statement

# %%
income_statement = get_income_statement(ticker, api_key, 'annual')
income_statement
# Out:
# date                                2019-09-28    2018-09-29    2017-09-30  \
# fillingDate                         2019-10-31    2018-11-05    2017-11-03
# period                                      FY            FY            FY
# revenue                           260174000000  265595000000  229234000000
# costOfRevenue                     161782000000  163756000000  141048000000
# grossProfit                        98392000000  101839000000   88186000000
# grossProfitRatio                      0.378178      0.383437      0.384699
# researchAndDevelopmentExpenses     16217000000   14236000000   11581000000
# generalAndAdministrativeExpenses   18245000000   16705000000   15261000000
# sellingAndMarketingExpenses                  0             0             0
# otherExpenses                       1807000000             0    2745000000
# operatingExpenses                  34462000000   30941000000   26842000000
# costAndExpenses                   196244000000  194697000000  167890000000
# interestExpense                     3576000000    3240000000    2323000000
# depreciationAndAmortization        12547000000   10903000000   10157000000
# ebitda                             76477000000   81801000000   71501000000
# ebitdaratio                           0.293946      0.307991      0.311913
# operatingIncome                    63930000000   70898000000   61344000000
# operatingIncomeRatio                   0.24572       0.26694      0.267604
# totalOtherIncomeExpensesNet         1807000000    2005000000    2745000000
# incomeBeforeTax                    65737000000   72903000000   64089000000
# incomeBeforeTaxRatio                  0.252666      0.274489      0.279579
# incomeTaxExpense                   10481000000   13372000000   15738000000
# netIncome                          55256000000   59531000000   48351000000
# netIncomeRatio                        0.212381      0.224142      0.210924
# eps                                      11.97         12.01          9.27
# epsdiluted                               11.89         11.91          9.21
# weightedAverageShsOut               4617834000    4955377000    5217242000
# weightedAverageShsOutDil            4648913000    5000109000    5251692000
#
# date                                2016-09-24    2015-09-26    2014-09-27  \
# fillingDate                         2016-10-26    2015-10-28    2014-10-27
# period                                      FY            FY            FY
# revenue                           215639000000  233715000000  182795000000
# costOfRevenue                     131376000000  140089000000  112258000000
# grossProfit                        84263000000   93626000000   70537000000
# grossProfitRatio                       0.39076      0.400599       0.38588
# researchAndDevelopmentExpenses     10045000000    8067000000    6041000000
# generalAndAdministrativeExpenses   14194000000   14329000000   11993000000
# sellingAndMarketingExpenses                  0             0             0
# otherExpenses                       1348000000    1285000000     980000000
# operatingExpenses                  24239000000   22396000000   18034000000
# costAndExpenses                   155615000000  162485000000  130292000000
# interestExpense                     1456000000     733000000     384000000
# depreciationAndAmortization        10505000000   11257000000    7946000000
# ebitda                             70529000000   82487000000   60449000000
# ebitdaratio                            0.32707      0.352938      0.330693
# operatingIncome                    60024000000   71230000000   52503000000
# operatingIncomeRatio                  0.278354      0.304773      0.287223
# totalOtherIncomeExpensesNet         1348000000    1285000000     980000000
# incomeBeforeTax                    61372000000   72515000000   53483000000
# incomeBeforeTaxRatio                  0.284605      0.310271      0.292585
# incomeTaxExpense                   15685000000   19121000000   13973000000
# netIncome                          45687000000   53394000000   39510000000
# netIncomeRatio                        0.211868      0.228458      0.216144
# eps                                       8.35          9.28          6.49
# epsdiluted                                8.31          9.22          6.45
# weightedAverageShsOut               5470820000    5753421000    6085572000
# weightedAverageShsOutDil            5500281000    5793069000    6122663000
#
# date                                2013-09-28    2012-09-29    2011-09-24  \
# fillingDate                         2013-10-30    2012-10-31    2011-10-26
# period                                      FY            FY            FY
# revenue                           170910000000  156508000000  108249000000
# costOfRevenue                     106606000000   87846000000   64431000000
# grossProfit                        64304000000   68662000000   43818000000
# grossProfitRatio                      0.376245      0.438712      0.404789
# researchAndDevelopmentExpenses      4475000000    3381000000    2429000000
# generalAndAdministrativeExpenses   10830000000   10040000000    7599000000
# sellingAndMarketingExpenses                  0             0             0
# otherExpenses                       1156000000     522000000     415000000
# operatingExpenses                  15305000000   13421000000   10028000000
# costAndExpenses                   121911000000  101267000000   74459000000
# interestExpense                      136000000             0             0
# depreciationAndAmortization         6757000000    3277000000    1814000000
# ebitda                             55756000000   58518000000   35604000000
# ebitdaratio                            0.32623      0.373898      0.328908
# operatingIncome                    48999000000   55241000000   33790000000
# operatingIncomeRatio                  0.286695       0.35296      0.312151
# totalOtherIncomeExpensesNet         1156000000     522000000     415000000
# incomeBeforeTax                    50155000000   55763000000   34205000000
# incomeBeforeTaxRatio                  0.293459      0.356295      0.315984
# incomeTaxExpense                   13118000000   14030000000    8283000000
# netIncome                          37037000000   41733000000   25922000000
# netIncomeRatio                        0.216705      0.266651      0.239466
# eps                                      40.03         44.64         28.05
# epsdiluted                               39.75         44.15         27.68
# weightedAverageShsOut                925331000     934818000     924258000
# weightedAverageShsOutDil             931662000     945355000     936645000
#
# date                               2010-09-25   2009-09-26   2008-09-27  \
# fillingDate                        2010-10-27   2009-10-27   2008-11-05
# period                                     FY           FY           FY
# revenue                           65225000000  36537000000  32479000000
# costOfRevenue                     39541000000  23397000000  21334000000
# grossProfit                       25684000000  13140000000  11145000000
# grossProfitRatio                     0.393775     0.359635     0.343145
# researchAndDevelopmentExpenses     1782000000   1333000000   1109000000
# generalAndAdministrativeExpenses   5517000000   4149000000   3761000000
# sellingAndMarketingExpenses                 0            0            0
# otherExpenses                       155000000    326000000    620000000
# operatingExpenses                  7299000000   5482000000   4870000000
# costAndExpenses                   46840000000  28879000000  26204000000
# interestExpense                             0            0            0
# depreciationAndAmortization        1027000000    703000000    473000000
# ebitda                            19412000000   8361000000   6748000000
# ebitdaratio                          0.297616     0.228837     0.207765
# operatingIncome                   18385000000   7658000000   6275000000
# operatingIncomeRatio                  0.28187     0.209596     0.193202
# totalOtherIncomeExpensesNet         155000000    326000000    620000000
# incomeBeforeTax                   18540000000   7984000000   6895000000
# incomeBeforeTaxRatio                 0.284247     0.218518     0.212291
# incomeTaxExpense                   4527000000   2280000000   2061000000
# netIncome                         14013000000   5704000000   4834000000
# netIncomeRatio                       0.214841     0.156116     0.148835
# eps                                     15.41         6.39         5.48
# epsdiluted                              15.15         6.29         5.36
# weightedAverageShsOut               909461000    893016000    881592000
# weightedAverageShsOutDil            924712000    907005000    902139000
#
# date                               2007-09-29   2006-09-30   2005-09-24  \
# fillingDate                        2007-11-15   2006-12-29   2005-12-01
# period                                     FY           FY           FY
# revenue                           24006000000  13931000000  13931000000
# costOfRevenue                     15852000000   9888000000   9888000000
# grossProfit                        8154000000   4043000000   4043000000
# grossProfitRatio                     0.339665     0.290216     0.290216
# researchAndDevelopmentExpenses      782000000    534000000    534000000
# generalAndAdministrativeExpenses   2963000000   1859000000   1859000000
# sellingAndMarketingExpenses                 0            0            0
# otherExpenses                       599000000    165000000    165000000
# operatingExpenses                  3745000000   2393000000   2393000000
# costAndExpenses                   19597000000  12281000000  12281000000
# interestExpense                             0            0            0
# depreciationAndAmortization         317000000    225000000    179000000
# ebitda                             4726000000   1875000000   1829000000
# ebitdaratio                          0.196867     0.134592      0.13129
# operatingIncome                    4409000000   1650000000   1650000000
# operatingIncomeRatio                 0.183662     0.118441     0.118441
# totalOtherIncomeExpensesNet         599000000    165000000    165000000
# incomeBeforeTax                    5008000000   1815000000   1815000000
# incomeBeforeTaxRatio                 0.208615     0.130285     0.130285
# incomeTaxExpense                   1512000000    480000000    480000000
# netIncome                          3496000000   1335000000   1335000000
# netIncomeRatio                        0.14563    0.0958294    0.0958294
# eps                                      4.04         1.65         1.65
# epsdiluted                               3.93         1.56         1.56
# weightedAverageShsOut               864595000    808439000    808439000
# weightedAverageShsOutDil            889292000    856780000    856780000
#
# date                              2004-09-25   2003-09-27  2002-09-28  \
# fillingDate                       2004-12-03   2003-12-19  2002-12-19
# period                                    FY           FY          FY
# revenue                           8279000000   6207000000  5742000000
# costOfRevenue                     6020000000   4499000000  4139000000
# grossProfit                       2259000000   1708000000  1603000000
# grossProfitRatio                    0.272859     0.275173    0.279171
# researchAndDevelopmentExpenses     489000000    471000000   446000000
# generalAndAdministrativeExpenses  1421000000   1212000000  1111000000
# sellingAndMarketingExpenses                0            0           0
# otherExpenses                       23000000     26000000    29000000
# operatingExpenses                 1933000000   1709000000  1586000000
# costAndExpenses                   7953000000   6208000000  5725000000
# interestExpense                            0            0           0
# depreciationAndAmortization        150000000    113000000   118000000
# ebitda                             476000000    112000000   135000000
# ebitdaratio                        0.0574949    0.0180441    0.023511
# operatingIncome                    326000000     -1000000    17000000
# operatingIncomeRatio               0.0393767 -0.000161108  0.00296064
# totalOtherIncomeExpensesNet         53000000     83000000   112000000
# incomeBeforeTax                    383000000     92000000    87000000
# incomeBeforeTaxRatio               0.0462616     0.014822   0.0151515
# incomeTaxExpense                   107000000     24000000    22000000
# netIncome                          276000000     69000000    65000000
# netIncomeRatio                     0.0333374    0.0111165   0.0113201
# eps                                     0.74         0.19        0.18
# epsdiluted                              0.71         0.19        0.18
# weightedAverageShsOut              371590000    360631000   355022000
# weightedAverageShsOutDil           387311000    363466000   361785000
#
# date                              2001-09-29
# fillingDate                       2001-12-21
# period                                    FY
# revenue                           5363000000
# costOfRevenue                     4128000000
# grossProfit                       1235000000
# grossProfitRatio                    0.230282
# researchAndDevelopmentExpenses     430000000
# generalAndAdministrativeExpenses  1138000000
# sellingAndMarketingExpenses                0
# otherExpenses                       11000000
# operatingExpenses                 1579000000
# costAndExpenses                   5707000000
# interestExpense                            0
# depreciationAndAmortization        102000000
# ebitda                            -242000000
# ebitdaratio                        -0.045124
# operatingIncome                   -344000000
# operatingIncomeRatio              -0.0641432
# totalOtherIncomeExpensesNet        217000000
# incomeBeforeTax                    -52000000
# incomeBeforeTaxRatio             -0.00969607
# incomeTaxExpense                    15000000
# netIncome                           25000000
# netIncomeRatio                   -0.00466157
# eps                                    -0.11
# epsdiluted                             -0.11
# weightedAverageShsOut              345613000
# weightedAverageShsOutDil           345613000

# %% [markdown]
# ## Cash Flow Statement

# %%
cf = get_cash_flow_statement(ticker, api_key, 'quarterly', 8)
cf
# Out:
# date                                         2019-09-28    2018-09-29  \
# fillingDate                                  2019-10-31    2018-11-05
# period                                               FY            FY
# netIncome                                   55256000000   59531000000
# depreciationAndAmortization                 12547000000   10903000000
# deferredIncomeTax                             340000000   32590000000
# stockBasedCompensation                       6068000000    5340000000
# changeInWorkingCapital                      42628000000  -13358000000
# accountsReceivables                           245000000   -5322000000
# inventory                                    -289000000     828000000
# accountsPayables                            -1923000000    9175000000
# otherWorkingCapital                         57101000000   14473000000
# otherNonCashItems                                     0             0
# netCashProvidedByOperatingActivities        69391000000   77434000000
# investmentsInPropertyPlantAndEquipment     -10495000000  -13313000000
# acquisitionsNet                              -624000000    -721000000
# purchasesOfInvestments                    -107528000000  -74609000000
# salesMaturitiesOfInvestments                98724000000   56234000000
# otherInvestingActivites                     65819000000   48475000000
# netCashUsedForInvestingActivites            45896000000   16066000000
# debtRepayment                               -8805000000   -6500000000
# commonStockIssued                             781000000     669000000
# commonStockRepurchased                     -66897000000  -72738000000
# dividendsPaid                              -14119000000  -13712000000
# otherFinancingActivites                     -1936000000    4405000000
# netCashUsedProvidedByFinancingActivities   -90976000000  -87876000000
# effectOfForexChangesOnCash                            0             0
# netChangeInCash                             24311000000    5624000000
# cashAtEndOfPeriod                           50224000000   25913000000
# cashAtBeginningOfPeriod                     25913000000   20289000000
# operatingCashFlow                           69391000000   77434000000
# capitalExpenditure                          10495000000   13313000000
# freeCashFlow                                58896000000   64121000000
#
# date                                        2017-09-30    2016-09-24  \
# fillingDate                                 2017-11-03    2016-10-26
# period                                              FY            FY
# netIncome                                  48351000000   45687000000
# depreciationAndAmortization                10157000000   10505000000
# deferredIncomeTax                          -5966000000   -4938000000
# stockBasedCompensation                      4840000000    4210000000
# changeInWorkingCapital                       -32000000   19095000000
# accountsReceivables                        -2093000000    1095000000
# inventory                                  -2723000000     217000000
# accountsPayables                            9618000000    1791000000
# otherWorkingCapital                        27831000000   27863000000
# otherNonCashItems                                    0             0
# netCashProvidedByOperatingActivities       63598000000   65824000000
# investmentsInPropertyPlantAndEquipment    -12451000000  -12734000000
# acquisitionsNet                             -329000000    -297000000
# purchasesOfInvestments                    -33295000000  -31110000000
# salesMaturitiesOfInvestments               31775000000   21258000000
# otherInvestingActivites                   -32146000000  -23094000000
# netCashUsedForInvestingActivites          -46446000000  -45977000000
# debtRepayment                              -3500000000   -2500000000
# commonStockIssued                            555000000     495000000
# commonStockRepurchased                    -32900000000  -29722000000
# dividendsPaid                             -12769000000  -12150000000
# otherFinancingActivites                    31267000000   23394000000
# netCashUsedProvidedByFinancingActivities  -17347000000  -20483000000
# effectOfForexChangesOnCash                           0             0
# netChangeInCash                             -195000000    -636000000
# cashAtEndOfPeriod                          20289000000   20484000000
# cashAtBeginningOfPeriod                    20484000000   21120000000
# operatingCashFlow                          63598000000   65824000000
# capitalExpenditure                         12795000000   13548000000
# freeCashFlow                               50803000000   52276000000
#
# date                                        2015-09-26    2014-09-27  \
# fillingDate                                 2015-10-28    2014-10-27
# period                                              FY            FY
# netIncome                                  53394000000   39510000000
# depreciationAndAmortization                11257000000    7946000000
# deferredIncomeTax                          -1382000000   -2347000000
# stockBasedCompensation                      3586000000    2863000000
# changeInWorkingCapital                      3685000000  -24545000000
# accountsReceivables                          611000000   -4232000000
# inventory                                   -238000000     -76000000
# accountsPayables                            5400000000    5938000000
# otherWorkingCapital                         8768000000    5083000000
# otherNonCashItems                                    0             0
# netCashProvidedByOperatingActivities       81266000000   59713000000
# investmentsInPropertyPlantAndEquipment    -11247000000   -9571000000
# acquisitionsNet                             -343000000   -3765000000
# purchasesOfInvestments                    -35253000000  -45000000000
# salesMaturitiesOfInvestments               14538000000   18810000000
# otherInvestingActivites                   -23969000000   16947000000
# netCashUsedForInvestingActivites          -56274000000  -22579000000
# debtRepayment                              -1499000000   -1158000000
# commonStockIssued                            543000000     730000000
# commonStockRepurchased                    -35253000000  -45000000000
# dividendsPaid                             -11561000000  -11126000000
# otherFinancingActivites                    28555000000   17847000000
# netCashUsedProvidedByFinancingActivities  -17716000000  -37549000000
# effectOfForexChangesOnCash                           0             0
# netChangeInCash                             7276000000    -415000000
# cashAtEndOfPeriod                          21120000000   13844000000
# cashAtBeginningOfPeriod                    13844000000   14259000000
# operatingCashFlow                          81266000000   59713000000
# capitalExpenditure                         11488000000    9813000000
# freeCashFlow                               69778000000   49900000000
#
# date                                        2013-09-28     2012-09-29
# fillingDate                                 2013-10-30     2012-10-31
# period                                              FY             FY
# netIncome                                  37037000000    41733000000
# depreciationAndAmortization                 6757000000     3277000000
# deferredIncomeTax                          -1141000000    -4405000000
# stockBasedCompensation                      2253000000     1740000000
# changeInWorkingCapital                     10517000000     2093000000
# accountsReceivables                        -2172000000    -5551000000
# inventory                                   -973000000      -15000000
# accountsPayables                            2340000000     4467000000
# otherWorkingCapital                        29628000000    19111000000
# otherNonCashItems                                    0              0
# netCashProvidedByOperatingActivities       53666000000    50856000000
# investmentsInPropertyPlantAndEquipment     -8165000000    -8295000000
# acquisitionsNet                             -496000000     -350000000
# purchasesOfInvestments                    -22860000000  -151232000000
# salesMaturitiesOfInvestments               20317000000    13035000000
# otherInvestingActivites                   -22570000000   -52617000000
# netCashUsedForInvestingActivites          -33774000000   -48227000000
# debtRepayment                              -1082000000    -1226000000
# commonStockIssued                            530000000      665000000
# commonStockRepurchased                    -22860000000   -10746000000
# dividendsPaid                             -10564000000    -2488000000
# otherFinancingActivites                    16515000000    10871000000
# netCashUsedProvidedByFinancingActivities  -16379000000    -1698000000
# effectOfForexChangesOnCash                           0              0
# netChangeInCash                             3513000000      931000000
# cashAtEndOfPeriod                          14259000000    10746000000
# cashAtBeginningOfPeriod                    10746000000     9815000000
# operatingCashFlow                          53666000000    50856000000
# capitalExpenditure                          9076000000     9402000000
# freeCashFlow                               44590000000    41454000000

# %% [markdown]
# ## Plot of Past Cash Flows

# %%
# graph annual cash flows
fig = make_subplots(rows=1, cols=1, start_cell="top-left")

fig.add_trace(go.Bar(name="Cash Flows", 
                     x=cf.columns, 
                     y=cf.iloc[-1], 
                     text=cf.iloc[-1], 
                     textposition='outside', 
                     marker_color='#2ca02c',
                     texttemplate = "$%{text:,.0f}"), 
              row=1, col=1)

fig.update_layout(
    title="{} Cash Flows".format(ticker),
    xaxis_title="Year",
    yaxis_title="Dollars")

display(tag)
fig.show()
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#     if (code_show){
#         $('div.cell.code_cell.rendered.selected div.input').hide();
#     } else {
#         $('div.cell.code_cell.rendered.selected div.input').show();
#     }
#     code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# To show/hide this cell's raw code input, click <a href="javascript:code_toggle()">here</a>.
# <div>
#
#
#             <div id="f204b060-acdf-4593-b11a-86ec79a64d1f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f204b060-acdf-4593-b11a-86ec79a64d1f")) {
#                     Plotly.newPlot(
#                         'f204b060-acdf-4593-b11a-86ec79a64d1f',
#                         [{"marker": {"color": "#2ca02c"}, "name": "Cash Flows", "text": [58896000000, 64121000000, 50803000000, 52276000000, 69778000000, 49900000000, 44590000000, 41454000000], "textposition": "outside", "texttemplate": "$%{text:,.0f}", "type": "bar", "x": ["2019-09-28", "2018-09-29", "2017-09-30", "2016-09-24", "2015-09-26", "2014-09-27", "2013-09-28", "2012-09-29"], "xaxis": "x", "y": [58896000000, 64121000000, 50803000000, 52276000000, 69778000000, 49900000000, 44590000000, 41454000000], "yaxis": "y"}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {" ...

# %% [markdown]
# ## Determine the Average Growth Rate of Cash Flows
#
# Note: you can choose to use this in your DCF calculation explicity in DCF Inputs box, otherwise it does not impact the valuation model

# %%
# get average cash flow growth over the past x periods

# obtain the years and cash flow values of past years from the cashflow statement
periods = len(cf.iloc[-1])
cash_flows = list(cf.iloc[-1])

growth_rates = []

# loop through the past cash flows and calculate each years growth
for i in range(periods-1):
    div_g_rate = (cash_flows[-(i+2)]-cash_flows[-(i+1)])/cash_flows[-(i+2)]
    growth_rates.append(div_g_rate)

# sum the growths and divide by the number of years to get the average
avg_g_rate = sum(growth_rates)/periods
print(" {}%".format(round(avg_g_rate*100,2)))
# Out:
#  2.71%

# %%
# this is the main time value calculation based on the dcf inputs provided
x = (1+g_rate)/(1+discount_rate)
y = (1+t_rate)/(1+discount_rate)

try:
    z = x * (1-x**g_years)/(1-x) + (x**g_years)*y*(1-y**t_years)/(1-y)
except:
    growth_contrib = 0
    term_contrib = 0
    
    for i in range(g_years):
        growth_contrib += x**(i+1)
        
    for i in range(t_years):
        term_contrib += y**(i+1)
    
    term_contrib = (x**g_years)*term_contrib
        
    z = growth_contrib + term_contrib

z
# Out:
# 28.468298270661705

# %% [markdown]
# ### DCF Valuation

# %%
# calculate the free cash flow per share from the cash flow statement
fcf_per_share = cash_flows[0]/quote.loc['Shares Outstanding'][0]
fcf_per_share
# Out:
# 13.58826025938642

# %%
if fcf_per_share < 0:
    fcf_dcf = 0
else:
    fcf_dcf = fcf_per_share*z
    
print("${}".format(round(fcf_dcf,2)))
# Out:
# $386.83

# %% [markdown]
# ### EPS Valuation

# %%
# get the eps from the stock quote
eps = quote.loc['EPS'][0]
eps
# Out:
# 12.728

# %%
if eps < 0 :
    eps_dcf = 0
else:
    eps_dcf = eps*z
    
print("${}".format(round(eps_dcf,2)))
# Out:
# $362.34

# %% [markdown]
# ### Margin Of Safety

# %%
if fcf_dcf == 0:
    mos_fcf = -1
else:
    mos_fcf = (fcf_dcf - quote.loc['Price'][0])/fcf_dcf
    
if eps_dcf == 0:
    mos_eps = -1
else:
    mos_eps = (eps_dcf - quote.loc['Price'][0])/eps_dcf

print("DCF: {}%".format(round(mos_fcf*100,2)))
print("EPS Valuation: {}%".format(round(mos_eps*100,2)))
# Out:
# DCF: 12.54%
# EPS Valuation: 6.63%

# %% [markdown]
# # DDM
# ### Discount Dividend Model
#
# Note: The classic dividend discount model works best when valuing a mature company that pays a hefty portion of its earnings as dividends, such as a utility company
#
# The DDM has various limitations including its inability to effectively work with high growth stocks. If the company's dividend growth rate exceeds the expected return rate, you cannot calculate a value because you get a negative denominator in the formula. Stocks don't have a negative value. Consider a company with a dividend growing at 20% while the expected return rate is only 5%: in the denominator (r-g), you would have -15% (5% - 20%).
#
# Moreover, if you hope to value a growth stock with the dividend discount model, your valuation will be based on nothing more than guesses about the company's future profits and dividend policy decisions. Most growth stocks don't pay out dividends. Rather, they re-invest earnings into the company with the hope of providing shareholders with returns by means of a higher share price.

# %%
# get historical dividend paid out per share
url = 'https://financialmodelingprep.com/api/v3/historical-price-full/stock_dividend/{}?apikey={}'.format(ticker, api_key)

d = requests.get(url)

divs_json = json.loads(d.text)

try:
    dividends = pd.DataFrame(divs_json["historical"], columns=['date','adjDividend']).set_index('date')
    dividends.index = pd.to_datetime(dividends.index, format='%Y/%m/%d')
except:
    log_error("Historical Dividends Are Not Available at this time Or the company has no dividends", divs_json)
    dividends = None

# %%
# sometimes stocks dont have dividends (growth stocks), so we cannot use DDM
dividends
# Out:
#             adjDividend
# date
# 2020-05-08      0.82000
# 2020-02-07      0.77000
# 2019-11-07      0.77000
# 2019-08-09      0.77000
# 2019-05-10      0.77000
# ...                 ...
# 1988-05-16      0.00286
# 1988-02-12      0.00286
# 1987-11-17      0.00286
# 1987-08-10      0.00214
# 1987-05-11      0.00214
#
# [67 rows x 1 columns]

# %%
avg_grate = 0

if dividends is not None:
    
# obtain dividend growth rate
    div_grates = []

    years = sorted(list(set(dividends.index.year)))
    last_yr = years[-1]

    for year in years[:-1]: 
        div_yr1 = dividends[dividends.index.year == year].sum()[0]
    
        if year+1 != last_yr:
            div_yr2 = dividends[dividends.index.year == year+1].sum()[0]
        else:
            div_yr2 = dividends[dividends.index.year == year+1].iloc[0][0]*4
            final_div = div_yr2
    
        div_growth = (div_yr2-div_yr1)/div_yr1
    
        if div_growth > .5 or div_growth < -0.4:
            continue
        else:
            div_grates.append(div_growth)
    
    avg_grate = round(sum(div_grates)/len(div_grates),2)

print("Calculated Average Dividend Growth: {}%".format(avg_grate*100))
# Out:
# Calculated Average Dividend Growth: 8.0%

# %%
next_yr_div = 0

if dividends is not None:
    next_yr_div = round(final_div*(1+avg_grate),2)

print("Predicted Dividend: ${}".format(next_yr_div))
# Out:
# Predicted Dividend: $3.54

# %% [markdown]
# #### DDM Equation
# $D_0/(r-g)$
#
# where
#
# $D_0$ = Next Years Dividend
#
# $r$ = Expected Rate of Return (Discount Rate)
#
# $g$ = Dividend Growth Rate

# %%
if dividends is not None:
    if discount_rate == avg_grate:
        discount_rate += 0.01
    
    ddm = next_yr_div/(discount_rate-avg_grate)
    print("DDM Value: ${}".format(ddm))
# Out:
# DDM Value: $88.50000000000001
